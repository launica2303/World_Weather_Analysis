# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=76b38af97a357ad7480a66b11bac7a03

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Retrieve the Latitude and longitude,Maximum temperature,Percent humidity,
# Percent cloudiness,Wind speed from the API call:

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Retrieve the  Weather description from the API call:
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | puerto carreno
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | tommot
# Processing Record 10 of Set 1 | lavrentiya
# Processing Record 11 of Set 1 | torbay
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | kingaroy
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | kieta
# Processing Record 16 of Set 1 | batagay-alyta
# Processing Record 17 of Set 1 | korgen
# Processing Record 18 of Set 1 | abha
# Processing Record 19 of Set 1 | simbahan
# Processing Record 20 of Set 1 | isla vista
# Processing Record 21 of Set 1 | chuy
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 1 | wote
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | mackay
# Processing Record 28 of Set 1 | airai
# Processing Record 29 of Set 1 | hamilton
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | santiago del estero
# Processing Record 33 of Set 1 | pisco
# Processing Record 34 of Set 1 | whitianga
# Processing Record 35 of Set 1 | clyde river
# Processing Record 36 of Set 1 | berlevag
# Processing Record 37 of Set 1 | nikolskoye
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | antioch
# Processing Record 40 of Set 1 | gat
# Processing Record 41 of Set 1 | sabha
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | soe
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | port blair
# Processing Record 46 of Set 1 | beringovskiy
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | ginda
# Processing Record 1 of Set 2 | henties bay
# Processing Record 2 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | lufilufi
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | tuktoyaktuk
# Processing Record 8 of Set 2 | berezanskaya
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | mountain home
# Processing Record 11 of Set 2 | cockburn town
# Processing Record 12 of Set 2 | port lincoln
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | la orilla
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | chulman
# Processing Record 18 of Set 2 | maniitsoq
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | paka
# Processing Record 21 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 2 | xai-xai
# Processing Record 23 of Set 2 | betioky
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | severo-yeniseyskiy
# Processing Record 27 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 2 | norman wells
# Processing Record 29 of Set 2 | merauke
# Processing Record 30 of Set 2 | suntar
# Processing Record 31 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 2 | chapais
# Processing Record 33 of Set 2 | nyagan
# Processing Record 34 of Set 2 | ponta delgada
# Processing Record 35 of Set 2 | severo-kurilsk
# Processing Record 36 of Set 2 | katsuura
# Processing Record 37 of Set 2 | thinadhoo
# Processing Record 38 of Set 2 | san quintin
# Processing Record 39 of Set 2 | vostok
# Processing Record 40 of Set 2 | road town
# Processing Record 41 of Set 2 | leh
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | alto longa
# Processing Record 45 of Set 2 | pevek
# Processing Record 46 of Set 2 | luderitz
# Processing Record 47 of Set 2 | poum
# Processing Record 48 of Set 2 | leningradskiy
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 1 of Set 3 | castro
# Processing Record 2 of Set 3 | matara
# Processing Record 3 of Set 3 | fukue
# Processing Record 4 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 3 | bluff
# Processing Record 6 of Set 3 | fairbanks
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | hermanus
# Processing Record 10 of Set 3 | santa catarina de tepehuanes
# Processing Record 11 of Set 3 | bilma
# Processing Record 12 of Set 3 | senanga
# Processing Record 13 of Set 3 | sampit
# Processing Record 14 of Set 3 | port keats
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | othonoi
# City not found. Skipping...
# Processing Record 17 of Set 3 | williams lake
# Processing Record 18 of Set 3 | taltal
# Processing Record 19 of Set 3 | atuona
# Processing Record 20 of Set 3 | ondarroa
# Processing Record 21 of Set 3 | faanui
# Processing Record 22 of Set 3 | arlit
# Processing Record 23 of Set 3 | portland
# Processing Record 24 of Set 3 | raudeberg
# Processing Record 25 of Set 3 | okha
# Processing Record 26 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 3 | uinskoye
# Processing Record 28 of Set 3 | benoy
# Processing Record 29 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 3 | mount isa
# Processing Record 31 of Set 3 | kupang
# Processing Record 32 of Set 3 | acarau
# Processing Record 33 of Set 3 | lorengau
# Processing Record 34 of Set 3 | oudtshoorn
# Processing Record 35 of Set 3 | esperance
# Processing Record 36 of Set 3 | goundam
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | cagayan de oro
# Processing Record 39 of Set 3 | walvis bay
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | trairi
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 3 | oistins
# Processing Record 45 of Set 3 | riverton
# Processing Record 46 of Set 3 | kaitangata
# Processing Record 47 of Set 3 | bulungu
# Processing Record 48 of Set 3 | muncar
# Processing Record 49 of Set 3 | moranbah
# Processing Record 50 of Set 3 | rimbey
# Processing Record 1 of Set 4 | taoudenni
# Processing Record 2 of Set 4 | killybegs
# Processing Record 3 of Set 4 | tuy hoa
# Processing Record 4 of Set 4 | hvide sande
# Processing Record 5 of Set 4 | wajir
# Processing Record 6 of Set 4 | purpe
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | mabay
# Processing Record 9 of Set 4 | kirakira
# Processing Record 10 of Set 4 | san patricio
# Processing Record 11 of Set 4 | gillette
# Processing Record 12 of Set 4 | guerrero negro
# Processing Record 13 of Set 4 | sarab
# Processing Record 14 of Set 4 | graaff-reinet
# Processing Record 15 of Set 4 | richards bay
# Processing Record 16 of Set 4 | newport
# Processing Record 17 of Set 4 | pacific grove
# Processing Record 18 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 4 | bosaso
# Processing Record 20 of Set 4 | bathsheba
# Processing Record 21 of Set 4 | arsk
# Processing Record 22 of Set 4 | dikson
# Processing Record 23 of Set 4 | hasaki
# Processing Record 24 of Set 4 | sungaipenuh
# Processing Record 25 of Set 4 | itarema
# Processing Record 26 of Set 4 | turkistan
# Processing Record 27 of Set 4 | klaksvik
# Processing Record 28 of Set 4 | gannan
# Processing Record 29 of Set 4 | lawrenceburg
# Processing Record 30 of Set 4 | port moresby
# Processing Record 31 of Set 4 | tuatapere
# Processing Record 32 of Set 4 | hobyo
# Processing Record 33 of Set 4 | yashkul
# Processing Record 34 of Set 4 | cidreira
# Processing Record 35 of Set 4 | vila velha
# Processing Record 36 of Set 4 | puerto escondido
# Processing Record 37 of Set 4 | lakselv
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | provideniya
# Processing Record 40 of Set 4 | thunder bay
# Processing Record 41 of Set 4 | westport
# Processing Record 42 of Set 4 | pimentel
# Processing Record 43 of Set 4 | tukan
# Processing Record 44 of Set 4 | berdigestyakh
# Processing Record 45 of Set 4 | nouakchott
# Processing Record 46 of Set 4 | vardo
# Processing Record 47 of Set 4 | upernavik
# Processing Record 48 of Set 4 | aklavik
# Processing Record 49 of Set 4 | geraldton
# Processing Record 50 of Set 4 | nanortalik
# Processing Record 1 of Set 5 | chaman
# Processing Record 2 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 5 | zarate
# Processing Record 4 of Set 5 | andarab
# City not found. Skipping...
# Processing Record 5 of Set 5 | biltine
# Processing Record 6 of Set 5 | abonnema
# Processing Record 7 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 5 | nalut
# Processing Record 9 of Set 5 | santa isabel
# Processing Record 10 of Set 5 | kalomo
# City not found. Skipping...
# Processing Record 11 of Set 5 | mikuni
# Processing Record 12 of Set 5 | turukhansk
# Processing Record 13 of Set 5 | carnarvon
# Processing Record 14 of Set 5 | troitskoye
# Processing Record 15 of Set 5 | voronovytsya
# Processing Record 16 of Set 5 | zagan
# Processing Record 17 of Set 5 | marau
# Processing Record 18 of Set 5 | ciudad bolivar
# Processing Record 19 of Set 5 | kato mazarakion
# Processing Record 20 of Set 5 | ilulissat
# Processing Record 21 of Set 5 | tatawin
# Processing Record 22 of Set 5 | toulepleu
# City not found. Skipping...
# Processing Record 23 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 5 | magangue
# Processing Record 25 of Set 5 | aitape
# Processing Record 26 of Set 5 | oneonta
# Processing Record 27 of Set 5 | port antonio
# Processing Record 28 of Set 5 | ashcroft
# Processing Record 29 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | byron bay
# Processing Record 32 of Set 5 | weligama
# Processing Record 33 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 5 | ballina
# Processing Record 35 of Set 5 | beloha
# Processing Record 36 of Set 5 | bubaque
# Processing Record 37 of Set 5 | puri
# Processing Record 38 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 39 of Set 5 | victoria
# Processing Record 40 of Set 5 | bredasdorp
# Processing Record 41 of Set 5 | nadym
# Processing Record 42 of Set 5 | whitehorse
# Processing Record 43 of Set 5 | tanshui
# City not found. Skipping...
# Processing Record 44 of Set 5 | vestmanna
# Processing Record 45 of Set 5 | havelock
# Processing Record 46 of Set 5 | tevaitoa
# Processing Record 47 of Set 5 | xining
# Processing Record 48 of Set 5 | alice springs
# Processing Record 49 of Set 5 | mezen
# Processing Record 50 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 6 | cabo san lucas
# Processing Record 2 of Set 6 | horta
# Processing Record 3 of Set 6 | deputatskiy
# Processing Record 4 of Set 6 | tubuala
# Processing Record 5 of Set 6 | ust-omchug
# Processing Record 6 of Set 6 | adrar
# Processing Record 7 of Set 6 | sistranda
# Processing Record 8 of Set 6 | iqaluit
# Processing Record 9 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 6 | jeremie
# Processing Record 11 of Set 6 | tukrah
# Processing Record 12 of Set 6 | saint-joseph
# Processing Record 13 of Set 6 | dingle
# Processing Record 14 of Set 6 | erenhot
# Processing Record 15 of Set 6 | rio grande
# Processing Record 16 of Set 6 | koumac
# Processing Record 17 of Set 6 | palmer
# Processing Record 18 of Set 6 | madimba
# Processing Record 19 of Set 6 | saskylakh
# Processing Record 20 of Set 6 | ribeira grande
# Processing Record 21 of Set 6 | labuhan
# Processing Record 22 of Set 6 | ahipara
# Processing Record 23 of Set 6 | plettenberg bay
# Processing Record 24 of Set 6 | chernitsyno
# Processing Record 25 of Set 6 | innoshima
# Processing Record 26 of Set 6 | port alfred
# Processing Record 27 of Set 6 | andrelandia
# Processing Record 28 of Set 6 | kantang
# Processing Record 29 of Set 6 | kalmar
# Processing Record 30 of Set 6 | akyab
# Processing Record 31 of Set 6 | balabac
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | salinopolis
# Processing Record 34 of Set 6 | mons
# Processing Record 35 of Set 6 | avallon
# Processing Record 36 of Set 6 | kloulklubed
# Processing Record 37 of Set 6 | georgetown
# Processing Record 38 of Set 6 | kahului
# Processing Record 39 of Set 6 | shitanjing
# Processing Record 40 of Set 6 | padang
# Processing Record 41 of Set 6 | husavik
# Processing Record 42 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 43 of Set 6 | junction city
# Processing Record 44 of Set 6 | san ignacio
# Processing Record 45 of Set 6 | tasiilaq
# Processing Record 46 of Set 6 | meulaboh
# Processing Record 47 of Set 6 | port hardy
# Processing Record 48 of Set 6 | bako
# Processing Record 49 of Set 6 | puerto ayacucho
# Processing Record 50 of Set 6 | tianpeng
# Processing Record 1 of Set 7 | nioro
# Processing Record 2 of Set 7 | buala
# Processing Record 3 of Set 7 | cap malheureux
# Processing Record 4 of Set 7 | pangkalanbuun
# Processing Record 5 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 7 | mahonda
# Processing Record 7 of Set 7 | ketchikan
# Processing Record 8 of Set 7 | mantua
# Processing Record 9 of Set 7 | save
# Processing Record 10 of Set 7 | kabinda
# Processing Record 11 of Set 7 | pauini
# Processing Record 12 of Set 7 | macusani
# Processing Record 13 of Set 7 | quetzaltepec
# City not found. Skipping...
# Processing Record 14 of Set 7 | mahanoro
# Processing Record 15 of Set 7 | adeje
# Processing Record 16 of Set 7 | ascension
# Processing Record 17 of Set 7 | brawley
# Processing Record 18 of Set 7 | madang
# Processing Record 19 of Set 7 | ballitoville
# Processing Record 20 of Set 7 | fort saint james
# Processing Record 21 of Set 7 | nichinan
# Processing Record 22 of Set 7 | tambul
# City not found. Skipping...
# Processing Record 23 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 7 | pangnirtung
# Processing Record 25 of Set 7 | manokwari
# Processing Record 26 of Set 7 | knysna
# Processing Record 27 of Set 7 | plattling
# Processing Record 28 of Set 7 | atar
# Processing Record 29 of Set 7 | lar
# Processing Record 30 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 7 | egvekinot
# Processing Record 34 of Set 7 | mataram
# Processing Record 35 of Set 7 | college
# Processing Record 36 of Set 7 | myitkyina
# Processing Record 37 of Set 7 | casma
# Processing Record 38 of Set 7 | akureyri
# Processing Record 39 of Set 7 | klamath falls
# Processing Record 40 of Set 7 | tarquinia
# Processing Record 41 of Set 7 | codrington
# Processing Record 42 of Set 7 | gushikawa
# Processing Record 43 of Set 7 | yermolayevo
# Processing Record 44 of Set 7 | lai
# Processing Record 45 of Set 7 | nome
# Processing Record 46 of Set 7 | quito
# Processing Record 47 of Set 7 | senno
# Processing Record 48 of Set 7 | hami
# Processing Record 49 of Set 7 | buraydah
# Processing Record 50 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 8 | bethel
# Processing Record 2 of Set 8 | okhotsk
# Processing Record 3 of Set 8 | jamnah
# City not found. Skipping...
# Processing Record 4 of Set 8 | caravelas
# Processing Record 5 of Set 8 | constitucion
# Processing Record 6 of Set 8 | vallenar
# Processing Record 7 of Set 8 | tahe
# Processing Record 8 of Set 8 | sibolga
# Processing Record 9 of Set 8 | high level
# Processing Record 10 of Set 8 | rocha
# Processing Record 11 of Set 8 | port augusta
# Processing Record 12 of Set 8 | mayo
# Processing Record 13 of Set 8 | san rafael
# Processing Record 14 of Set 8 | agadir
# Processing Record 15 of Set 8 | zhaotong
# Processing Record 16 of Set 8 | erdenet
# Processing Record 17 of Set 8 | bengkulu
# Processing Record 18 of Set 8 | nouadhibou
# Processing Record 19 of Set 8 | northam
# Processing Record 20 of Set 8 | nemuro
# Processing Record 21 of Set 8 | mount gambier
# Processing Record 22 of Set 8 | christchurch
# Processing Record 23 of Set 8 | flinders
# Processing Record 24 of Set 8 | port hawkesbury
# Processing Record 25 of Set 8 | broome
# Processing Record 26 of Set 8 | ugoofaaru
# Processing Record 27 of Set 8 | lososina
# Processing Record 28 of Set 8 | doha
# Processing Record 29 of Set 8 | kamarion
# Processing Record 30 of Set 8 | samarai
# Processing Record 31 of Set 8 | bilibino
# Processing Record 32 of Set 8 | hambantota
# Processing Record 33 of Set 8 | chicama
# Processing Record 34 of Set 8 | anadyr
# Processing Record 35 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 8 | port elizabeth
# Processing Record 37 of Set 8 | muros
# Processing Record 38 of Set 8 | kawalu
# Processing Record 39 of Set 8 | vanavara
# Processing Record 40 of Set 8 | tondano
# Processing Record 41 of Set 8 | caraballeda
# Processing Record 42 of Set 8 | yulara
# Processing Record 43 of Set 8 | mount vernon
# Processing Record 44 of Set 8 | isangel
# Processing Record 45 of Set 8 | george
# Processing Record 46 of Set 8 | cherskiy
# Processing Record 47 of Set 8 | abu kamal
# Processing Record 48 of Set 8 | ardakan
# Processing Record 49 of Set 8 | kununurra
# Processing Record 50 of Set 8 | ibiruba
# Processing Record 1 of Set 9 | port-gentil
# Processing Record 2 of Set 9 | martapura
# Processing Record 3 of Set 9 | channel-port aux basques
# Processing Record 4 of Set 9 | vaitape
# Processing Record 5 of Set 9 | skibbereen
# Processing Record 6 of Set 9 | sugod
# Processing Record 7 of Set 9 | batemans bay
# Processing Record 8 of Set 9 | kizema
# Processing Record 9 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 10 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 9 | conakry
# Processing Record 12 of Set 9 | laguna
# Processing Record 13 of Set 9 | alofi
# Processing Record 14 of Set 9 | asau
# Processing Record 15 of Set 9 | troy
# Processing Record 16 of Set 9 | songling
# Processing Record 17 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 9 | ponta do sol
# Processing Record 19 of Set 9 | fare
# Processing Record 20 of Set 9 | bahia blanca
# Processing Record 21 of Set 9 | millinocket
# Processing Record 22 of Set 9 | broken hill
# Processing Record 23 of Set 9 | ponorogo
# Processing Record 24 of Set 9 | cayenne
# Processing Record 25 of Set 9 | tecoanapa
# Processing Record 26 of Set 9 | saint-georges
# Processing Record 27 of Set 9 | mesquite
# Processing Record 28 of Set 9 | yeniseysk
# Processing Record 29 of Set 9 | upata
# Processing Record 30 of Set 9 | dalianwan
# Processing Record 31 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 9 | vidim
# Processing Record 33 of Set 9 | salalah
# Processing Record 34 of Set 9 | marzuq
# Processing Record 35 of Set 9 | carnot
# Processing Record 36 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 9 | nizhniy baskunchak
# Processing Record 38 of Set 9 | nosy varika
# Processing Record 39 of Set 9 | loviisa
# Processing Record 40 of Set 9 | bishna
# City not found. Skipping...
# Processing Record 41 of Set 9 | quatre cocos
# Processing Record 42 of Set 9 | makakilo city
# Processing Record 43 of Set 9 | yar-sale
# Processing Record 44 of Set 9 | humaita
# Processing Record 45 of Set 9 | port said
# Processing Record 46 of Set 9 | yuzhou
# Processing Record 47 of Set 9 | san rafael del sur
# Processing Record 48 of Set 9 | port-cartier
# Processing Record 49 of Set 9 | lazaro cardenas
# Processing Record 50 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 1 of Set 10 | karakulino
# Processing Record 2 of Set 10 | harwich
# Processing Record 3 of Set 10 | goderich
# Processing Record 4 of Set 10 | kholodnyy
# Processing Record 5 of Set 10 | touros
# Processing Record 6 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 10 | honiara
# Processing Record 8 of Set 10 | rundu
# Processing Record 9 of Set 10 | pokosnoye
# Processing Record 10 of Set 10 | imbituba
# Processing Record 11 of Set 10 | aporawan
# City not found. Skipping...
# Processing Record 12 of Set 10 | pithiviers
# Processing Record 13 of Set 10 | ust-kan
# Processing Record 14 of Set 10 | pathein
# Processing Record 15 of Set 10 | paamiut
# Processing Record 16 of Set 10 | el alto
# Processing Record 17 of Set 10 | tokzar
# City not found. Skipping...
# Processing Record 18 of Set 10 | yushala
# Processing Record 19 of Set 10 | stornoway
# Processing Record 20 of Set 10 | shimoda
# Processing Record 21 of Set 10 | balud
# Processing Record 22 of Set 10 | denpasar
# Processing Record 23 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 10 | yeppoon
# Processing Record 25 of Set 10 | tazmalt
# Processing Record 26 of Set 10 | kalianget
# Processing Record 27 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 28 of Set 10 | boyolangu
# Processing Record 29 of Set 10 | agadez
# Processing Record 30 of Set 10 | peniche
# Processing Record 31 of Set 10 | darnah
# Processing Record 32 of Set 10 | mitsamiouli
# Processing Record 33 of Set 10 | nalgonda
# Processing Record 34 of Set 10 | rajnagar
# Processing Record 35 of Set 10 | maceio
# Processing Record 36 of Set 10 | kuandian
# Processing Record 37 of Set 10 | dongsheng
# Processing Record 38 of Set 10 | port macquarie
# Processing Record 39 of Set 10 | san
# Processing Record 40 of Set 10 | lagoa
# Processing Record 41 of Set 10 | sosnovo-ozerskoye
# Processing Record 42 of Set 10 | vertientes
# Processing Record 43 of Set 10 | te anau
# Processing Record 44 of Set 10 | tera
# Processing Record 45 of Set 10 | los llanos de aridane
# Processing Record 46 of Set 10 | kresttsy
# Processing Record 47 of Set 10 | burnie
# Processing Record 48 of Set 10 | molochnoye
# Processing Record 49 of Set 10 | barinas
# Processing Record 50 of Set 10 | olafsvik
# Processing Record 1 of Set 11 | saint george
# Processing Record 2 of Set 11 | sioux lookout
# Processing Record 3 of Set 11 | moron
# Processing Record 4 of Set 11 | alexandria
# Processing Record 5 of Set 11 | gotsu
# Processing Record 6 of Set 11 | yumen
# Processing Record 7 of Set 11 | saint-tite
# Processing Record 8 of Set 11 | safaga
# Processing Record 9 of Set 11 | chernyshevskiy
# Processing Record 10 of Set 11 | tiznit
# Processing Record 11 of Set 11 | burica
# City not found. Skipping...
# Processing Record 12 of Set 11 | svetlaya
# Processing Record 13 of Set 11 | emba
# Processing Record 14 of Set 11 | sangar
# Processing Record 15 of Set 11 | faranah
# Processing Record 16 of Set 11 | saldanha
# Processing Record 17 of Set 11 | proletarsk
# Processing Record 18 of Set 11 | salinas
# Processing Record 19 of Set 11 | igrim
# Processing Record 20 of Set 11 | girvan
# Processing Record 21 of Set 11 | yangjiang
# Processing Record 22 of Set 11 | havre-saint-pierre
# Processing Record 23 of Set 11 | banda aceh
# Processing Record 24 of Set 11 | sinnamary
# Processing Record 25 of Set 11 | kapoeta
# Processing Record 26 of Set 11 | joshimath
# Processing Record 27 of Set 11 | uyuni
# Processing Record 28 of Set 11 | svetlogorsk
# Processing Record 29 of Set 11 | vargem grande
# Processing Record 30 of Set 11 | takoradi
# Processing Record 31 of Set 11 | bulancak
# Processing Record 32 of Set 11 | rawson
# Processing Record 33 of Set 11 | tokmak
# Processing Record 34 of Set 11 | katherine
# Processing Record 35 of Set 11 | corinto
# Processing Record 36 of Set 11 | ostrovnoy
# Processing Record 37 of Set 11 | evensk
# Processing Record 38 of Set 11 | gambela
# Processing Record 39 of Set 11 | cannock
# Processing Record 40 of Set 11 | plaridel
# Processing Record 41 of Set 11 | margate
# Processing Record 42 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 43 of Set 11 | orlik
# Processing Record 44 of Set 11 | sangerhausen
# Processing Record 45 of Set 11 | abakaliki
# Processing Record 46 of Set 11 | srednekolymsk
# Processing Record 47 of Set 11 | tarakan
# Processing Record 48 of Set 11 | kavieng
# Processing Record 49 of Set 11 | praia da vitoria
# Processing Record 50 of Set 11 | guanare
# Processing Record 1 of Set 12 | hede
# Processing Record 2 of Set 12 | lethem
# Processing Record 3 of Set 12 | domoni
# Processing Record 4 of Set 12 | istok
# Processing Record 5 of Set 12 | eureka
# Processing Record 6 of Set 12 | sur
# Processing Record 7 of Set 12 | ancud
# Processing Record 8 of Set 12 | ankara
# Processing Record 9 of Set 12 | jaroslaw
# Processing Record 10 of Set 12 | aloleng
# Processing Record 11 of Set 12 | inirida
# Processing Record 12 of Set 12 | roma
# Processing Record 13 of Set 12 | pau brasil
# Processing Record 14 of Set 12 | maryborough
# Processing Record 15 of Set 12 | steamboat springs
# Processing Record 16 of Set 12 | chabahar
# Processing Record 17 of Set 12 | fortuna
# Processing Record 18 of Set 12 | komsomolskiy
# Processing Record 19 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 12 | asfi
# Processing Record 21 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 22 of Set 12 | amontada
# Processing Record 23 of Set 12 | antofagasta
# Processing Record 24 of Set 12 | narsaq
# Processing Record 25 of Set 12 | kisangani
# Processing Record 26 of Set 12 | puerto del rosario
# Processing Record 27 of Set 12 | bandarbeyla
# Processing Record 28 of Set 12 | aquiraz
# Processing Record 29 of Set 12 | qasigiannguit
# Processing Record 30 of Set 12 | benidorm
# Processing Record 31 of Set 12 | daru
# Processing Record 32 of Set 12 | zeya
# Processing Record 33 of Set 12 | reconquista
# Processing Record 34 of Set 12 | zhigansk
# Processing Record 35 of Set 12 | uong bi
# Processing Record 36 of Set 12 | fort nelson
# Processing Record 37 of Set 12 | atasu
# Processing Record 38 of Set 12 | paragominas
# Processing Record 39 of Set 12 | abu samrah
# Processing Record 40 of Set 12 | oga
# Processing Record 41 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 12 | chandler
# Processing Record 43 of Set 12 | oktyabrskiy
# Processing Record 44 of Set 12 | la macarena
# Processing Record 45 of Set 12 | mozelos
# Processing Record 46 of Set 12 | gobo
# Processing Record 47 of Set 12 | sabinas
# Processing Record 48 of Set 12 | birjand
# Processing Record 49 of Set 12 | saquarema
# Processing Record 50 of Set 12 | gao
# Processing Record 1 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 2 of Set 13 | skelleftea
# Processing Record 3 of Set 13 | aripuana
# Processing Record 4 of Set 13 | mwanza
# Processing Record 5 of Set 13 | bafq
# Processing Record 6 of Set 13 | florianopolis
# Processing Record 7 of Set 13 | russell
# Processing Record 8 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 13 | baghdad
# Processing Record 10 of Set 13 | balsta
# Processing Record 11 of Set 13 | asadabad
# Processing Record 12 of Set 13 | bonavista
# Processing Record 13 of Set 13 | kaka
# Processing Record 14 of Set 13 | arman
# Processing Record 15 of Set 13 | karpathos
# Processing Record 16 of Set 13 | ahuimanu
# Processing Record 17 of Set 13 | grindavik
# Processing Record 18 of Set 13 | iralaya
# Processing Record 19 of Set 13 | ruangwa
# Processing Record 20 of Set 13 | korla
# Processing Record 21 of Set 13 | ilave
# Processing Record 22 of Set 13 | wenling
# Processing Record 23 of Set 13 | neryungri
# Processing Record 24 of Set 13 | donskoye
# Processing Record 25 of Set 13 | bonnyville
# Processing Record 26 of Set 13 | rio blanco
# Processing Record 27 of Set 13 | karratha
# Processing Record 28 of Set 13 | staraya russa
# Processing Record 29 of Set 13 | avera
# Processing Record 30 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 31 of Set 13 | wawa
# Processing Record 32 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 13 | tomatlan
# Processing Record 34 of Set 13 | nanyang
# Processing Record 35 of Set 13 | marsa matruh
# Processing Record 36 of Set 13 | reshetylivka
# Processing Record 37 of Set 13 | solnechnyy
# Processing Record 38 of Set 13 | lewistown
# Processing Record 39 of Set 13 | zhuanghe
# Processing Record 40 of Set 13 | gumla
# Processing Record 41 of Set 13 | lompoc
# Processing Record 42 of Set 13 | livingston
# Processing Record 43 of Set 13 | saint-augustin
# Processing Record 44 of Set 13 | elizabeth city
# Processing Record 45 of Set 13 | mariental
# Processing Record 46 of Set 13 | manggar
# Processing Record 47 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 13 | verkhnyaya inta
# Processing Record 49 of Set 13 | tezu
# Processing Record 50 of Set 13 | verkhoyansk
# Processing Record 1 of Set 14 | haines junction
# Processing Record 2 of Set 14 | klintsy
# Processing Record 3 of Set 14 | sakakah
# Processing Record 4 of Set 14 | banepa
# Processing Record 5 of Set 14 | tocopilla
# Processing Record 6 of Set 14 | porto walter
# Processing Record 7 of Set 14 | sabang
# Processing Record 8 of Set 14 | najran
# Processing Record 9 of Set 14 | barao de melgaco
# Processing Record 10 of Set 14 | cabedelo
# Processing Record 11 of Set 14 | bronnoysund
# Processing Record 12 of Set 14 | llangefni
# Processing Record 13 of Set 14 | cavalcante
# Processing Record 14 of Set 14 | nhulunbuy
# Processing Record 15 of Set 14 | aleksandrov gay
# Processing Record 16 of Set 14 | kichera
# Processing Record 17 of Set 14 | bermejo
# Processing Record 18 of Set 14 | kastamonu
# Processing Record 19 of Set 14 | kruisfontein
# Processing Record 20 of Set 14 | mehamn
# Processing Record 21 of Set 14 | bud
# Processing Record 22 of Set 14 | biak
# Processing Record 23 of Set 14 | tarauaca
# Processing Record 24 of Set 14 | azul
# Processing Record 25 of Set 14 | abeche
# Processing Record 26 of Set 14 | coquimbo
# Processing Record 27 of Set 14 | picton
# Processing Record 28 of Set 14 | kalabo
# Processing Record 29 of Set 14 | chekhov
# Processing Record 30 of Set 14 | vao
# Processing Record 31 of Set 14 | boshan
# Processing Record 32 of Set 14 | noyabrsk
# Processing Record 33 of Set 14 | nikolayevka
# Processing Record 34 of Set 14 | manzanillo
# Processing Record 35 of Set 14 | kavaratti
# Processing Record 36 of Set 14 | lakes entrance
# Processing Record 37 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 38 of Set 14 | belaya gora
# Processing Record 39 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 14 | sheopur
# Processing Record 41 of Set 14 | aguimes
# Processing Record 42 of Set 14 | orbe
# Processing Record 43 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 14 | carahue
# Processing Record 46 of Set 14 | yokadouma
# Processing Record 47 of Set 14 | kindu
# Processing Record 48 of Set 14 | tabuk
# Processing Record 49 of Set 14 | cuamba
# Processing Record 50 of Set 14 | pergine valsugana
# Processing Record 1 of Set 15 | kirensk
# Processing Record 2 of Set 15 | grand gaube
# Processing Record 3 of Set 15 | manta
# Processing Record 4 of Set 15 | duncan
# Processing Record 5 of Set 15 | nargana
# Processing Record 6 of Set 15 | buritizeiro
# Processing Record 7 of Set 15 | haapiti
# Processing Record 8 of Set 15 | vacaria
# Processing Record 9 of Set 15 | itoman
# Processing Record 10 of Set 15 | palana
# Processing Record 11 of Set 15 | kriel
# Processing Record 12 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 13 of Set 15 | yerbogachen
# Processing Record 14 of Set 15 | virginia beach
# Processing Record 15 of Set 15 | the valley
# Processing Record 16 of Set 15 | owatonna
# Processing Record 17 of Set 15 | bentiu
# Processing Record 18 of Set 15 | derzhavinsk
# Processing Record 19 of Set 15 | ahome
# Processing Record 20 of Set 15 | ranong
# Processing Record 21 of Set 15 | ibra
# Processing Record 22 of Set 15 | ipil
# Processing Record 23 of Set 15 | bamako
# Processing Record 24 of Set 15 | alyangula
# Processing Record 25 of Set 15 | vila franca do campo
# Processing Record 26 of Set 15 | del rio
# Processing Record 27 of Set 15 | lima
# Processing Record 28 of Set 15 | morgan city
# Processing Record 29 of Set 15 | oranjemund
# Processing Record 30 of Set 15 | atherton
# Processing Record 31 of Set 15 | tilichiki
# Processing Record 32 of Set 15 | eyl
# Processing Record 33 of Set 15 | port hedland
# Processing Record 34 of Set 15 | boqueirao
# Processing Record 35 of Set 15 | necochea
# Processing Record 36 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 37 of Set 15 | scarborough
# Processing Record 38 of Set 15 | xiongyue
# Processing Record 39 of Set 15 | farafangana
# Processing Record 40 of Set 15 | lamar
# Processing Record 41 of Set 15 | qarchi gak
# Processing Record 42 of Set 15 | north bend
# Processing Record 43 of Set 15 | kampot
# Processing Record 44 of Set 15 | vila do maio
# Processing Record 45 of Set 15 | tahara
# Processing Record 46 of Set 15 | kaeo
# Processing Record 47 of Set 15 | san julian
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167     39.31        60           0
# 1    Longyearbyen      SJ  78.2186   15.6401     44.44        70          75
# 2  Puerto Carreno      CO   6.1890  -67.4859     78.19        85          82
# 3     Yellowknife      CA  62.4560 -114.3525     82.29        50          20
# 4     East London      ZA -33.0153   27.9116     66.04        30          93
# 5          Tommot      RU  58.9564  126.2925     54.64        71          93
# 6      Lavrentiya      RU  65.5833 -171.0000     43.34        86         100
# 7          Torbay      CA  47.6666  -52.7314     66.97        76          75
# 8  Saint-Philippe      RE -21.3585   55.7679     67.55        84          32
# 9        Kingaroy      AU -26.5333  151.8333     55.44       100          90
#
#    Wind Speed Current Description
# 0       17.27           clear sky
# 1       12.66       broken clouds
# 2        6.69       broken clouds
# 3       10.36          few clouds
# 4        6.55     overcast clouds
# 5        2.42     overcast clouds
# 6        7.87     overcast clouds
# 7       21.85       broken clouds
# 8       10.31          light rain
# 9        4.61                 fog

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
